# %%
import pandas as pd

# %%
url_confirmed = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
url_deaths = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
url_recovered = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'

# %%
confirmed = pd.read_csv(url_confirmed)
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  9/14/21  9/15/21  9/16/21  \
# 0        0        0        0        0  ...   154180   154283   154361
# 1        0        0        0        0  ...   158431   159423   160365
# 2        0        0        0        0  ...   200528   200770   200989
# 3        0        0        0        0  ...    15099    15108    15113
# 4        0        0        0        0  ...    51047    51407    51827
#
#    9/17/21  9/18/21  9/19/21  9/20/21  9/21/21  9/22/21  9/23/21
# 0   154487   154487   154487   154585   154712   154757   154800
# 1   161324   162173   162953   163404   164276   165096   165864
# 2   201224   201425   201600   201766   201948   202122   202283
# 3    15124    15124    15124    15140    15140    15153    15156
# 4    52208    52307    52307    52644    52968    53387    53840
#
# [5 rows x 615 columns]

# %%
date1 = confirmed.columns[4:]
total_confirmed = confirmed.melt(id_vars=['Province/State','Country/Region','Lat','Long'],
    value_vars=date1,
    var_name='date',
    value_name='confirmed')
total_confirmed.tail()
# Out:
#        Province/State      Country/Region        Lat        Long     date  \
# 170464            NaN             Vietnam  14.058324  108.277199  9/23/21
# 170465            NaN  West Bank and Gaza  31.952200   35.233200  9/23/21
# 170466            NaN               Yemen  15.552727   48.516388  9/23/21
# 170467            NaN              Zambia -13.133897   27.849332  9/23/21
# 170468            NaN            Zimbabwe -19.015438   29.154857  9/23/21
#
#         confirmed
# 170464     728435
# 170465     392452
# 170466       8830
# 170467     208715
# 170468     129134

# %%
deaths = pd.read_csv(url_deaths)
deaths.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  9/14/21  9/15/21  9/16/21  \
# 0        0        0        0        0  ...     7171     7174     7183
# 1        0        0        0        0  ...     2553     2557     2563
# 2        0        0        0        0  ...     5614     5630     5651
# 3        0        0        0        0  ...      130      130      130
# 4        0        0        0        0  ...     1358     1360     1371
#
#    9/17/21  9/18/21  9/19/21  9/20/21  9/21/21  9/22/21  9/23/21
# 0     7186     7186     7186     7199     7199     7199     7199
# 1     2569     2574     2580     2587     2594     2601     2609
# 2     5670     5681     5694     5709     5725     5739     5748
# 3      130      130      130      130      130      130      130
# 4     1378     1388     1388     1409     1414     1434     1460
#
# [5 rows x 615 columns]

# %%
date2 = deaths.columns[4:]
total_deaths = deaths.melt(id_vars=['Province/State','Country/Region','Lat','Long'],
    value_vars=date2,
    var_name='date',
    value_name='deaths')
total_deaths.tail()
# Out:
#        Province/State      Country/Region        Lat        Long     date  \
# 170464            NaN             Vietnam  14.058324  108.277199  9/23/21
# 170465            NaN  West Bank and Gaza  31.952200   35.233200  9/23/21
# 170466            NaN               Yemen  15.552727   48.516388  9/23/21
# 170467            NaN              Zambia -13.133897   27.849332  9/23/21
# 170468            NaN            Zimbabwe -19.015438   29.154857  9/23/21
#
#         deaths
# 170464   18017
# 170465    3980
# 170466    1664
# 170467    3641
# 170468    4600

# %%
recovered = pd.read_csv(url_recovered)
recovered.tail()
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 259            NaN             Vietnam  14.058324  108.277199        0
# 260            NaN  West Bank and Gaza  31.952200   35.233200        0
# 261            NaN               Yemen  15.552727   48.516388        0
# 262            NaN              Zambia -13.133897   27.849332        0
# 263            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/14/21  9/15/21  \
# 259        0        0        0        0        0  ...        0        0
# 260        0        0        0        0        0  ...        0        0
# 261        0        0        0        0        0  ...        0        0
# 262        0        0        0        0        0  ...        0        0
# 263        0        0        0        0        0  ...        0        0
#
#      9/16/21  9/17/21  9/18/21  9/19/21  9/20/21  9/21/21  9/22/21  9/23/21
# 259        0        0        0        0        0        0        0        0
# 260        0        0        0        0        0        0        0        0
# 261        0        0        0        0        0        0        0        0
# 262        0        0        0        0        0        0        0        0
# 263        0        0        0        0        0        0        0        0
#
# [5 rows x 615 columns]

# %%
date3 = recovered.columns[4:]
total_recovered = recovered.melt(id_vars=['Province/State','Country/Region','Lat','Long'],
    value_vars=date2,
    var_name='date',
    value_name='recovered')
total_recovered.tail()
# Out:
#        Province/State      Country/Region        Lat        Long     date  \
# 161299            NaN             Vietnam  14.058324  108.277199  9/23/21
# 161300            NaN  West Bank and Gaza  31.952200   35.233200  9/23/21
# 161301            NaN               Yemen  15.552727   48.516388  9/23/21
# 161302            NaN              Zambia -13.133897   27.849332  9/23/21
# 161303            NaN            Zimbabwe -19.015438   29.154857  9/23/21
#
#         recovered
# 161299          0
# 161300          0
# 161301          0
# 161302          0
# 161303          0

# %%
covid_data = total_confirmed.merge(right = total_deaths,
    how='left',
    on=['Province/State','Country/Region','Lat','Long','date'],
    )
covid_data.tail()
# Out:
#        Province/State      Country/Region        Lat        Long     date  \
# 170464            NaN             Vietnam  14.058324  108.277199  9/23/21
# 170465            NaN  West Bank and Gaza  31.952200   35.233200  9/23/21
# 170466            NaN               Yemen  15.552727   48.516388  9/23/21
# 170467            NaN              Zambia -13.133897   27.849332  9/23/21
# 170468            NaN            Zimbabwe -19.015438   29.154857  9/23/21
#
#         confirmed  deaths
# 170464     728435   18017
# 170465     392452    3980
# 170466       8830    1664
# 170467     208715    3641
# 170468     129134    4600

# %%
covid_data = covid_data.merge(right = total_recovered,
    how='left',
    on=['Province/State','Country/Region','Lat','Long','date'],
    )
covid_data.tail()
# Out:
#        Province/State      Country/Region        Lat        Long     date  \
# 170464            NaN             Vietnam  14.058324  108.277199  9/23/21
# 170465            NaN  West Bank and Gaza  31.952200   35.233200  9/23/21
# 170466            NaN               Yemen  15.552727   48.516388  9/23/21
# 170467            NaN              Zambia -13.133897   27.849332  9/23/21
# 170468            NaN            Zimbabwe -19.015438   29.154857  9/23/21
#
#         confirmed  deaths  recovered
# 170464     728435   18017        0.0
# 170465     392452    3980        0.0
# 170466       8830    1664        0.0
# 170467     208715    3641        0.0
# 170468     129134    4600        0.0

# %%
covid_data['date'] = pd.to_datetime(covid_data['date'])

# %%
covid_data.tail()
# Out:
#        Province/State      Country/Region        Lat        Long       date  \
# 170464            NaN             Vietnam  14.058324  108.277199 2021-09-23
# 170465            NaN  West Bank and Gaza  31.952200   35.233200 2021-09-23
# 170466            NaN               Yemen  15.552727   48.516388 2021-09-23
# 170467            NaN              Zambia -13.133897   27.849332 2021-09-23
# 170468            NaN            Zimbabwe -19.015438   29.154857 2021-09-23
#
#         confirmed  deaths  recovered
# 170464     728435   18017        0.0
# 170465     392452    3980        0.0
# 170466       8830    1664        0.0
# 170467     208715    3641        0.0
# 170468     129134    4600        0.0

# %%
covid_data.isna().sum()
# Out:
# Province/State    117312
# Country/Region         0
# Lat                 1222
# Long                1222
# date                   0
# confirmed              0
# deaths                 0
# recovered          12831
# dtype: int64

# %%
covid_data['recovered'] = covid_data['recovered'].fillna(0)

# %%
covid_data.isna().sum()
# Out:
# Province/State    117312
# Country/Region         0
# Lat                 1222
# Long                1222
# date                   0
# confirmed              0
# deaths                 0
# recovered              0
# dtype: int64

# %%
covid_data['active'] = covid_data['confirmed'] - covid_data['deaths'] - covid_data['recovered']

# %%
covid_data.tail()
# Out:
#        Province/State      Country/Region        Lat        Long       date  \
# 170464            NaN             Vietnam  14.058324  108.277199 2021-09-23
# 170465            NaN  West Bank and Gaza  31.952200   35.233200 2021-09-23
# 170466            NaN               Yemen  15.552727   48.516388 2021-09-23
# 170467            NaN              Zambia -13.133897   27.849332 2021-09-23
# 170468            NaN            Zimbabwe -19.015438   29.154857 2021-09-23
#
#         confirmed  deaths  recovered    active
# 170464     728435   18017        0.0  710418.0
# 170465     392452    3980        0.0  388472.0
# 170466       8830    1664        0.0    7166.0
# 170467     208715    3641        0.0  205074.0
# 170468     129134    4600        0.0  124534.0
